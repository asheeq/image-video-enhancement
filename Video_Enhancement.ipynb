# %% [markdown]
# <a href="https://colab.research.google.com/github/asheeq/image-video-enhancement/blob/master/Video_Enhancement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
from os.path import isfile, join
import time

# %%
vidcap = cv2.VideoCapture('/content/bunny.mp4')
success, image = vidcap.read()
count = 0
#frame_count = 1440

while success:
    save_name = 'frame' + str(count) + '.jpg'
    #-----Reading the image-----------------------------------------------------
    cv2.imwrite('/content/Input/' + save_name , image)
    img = cv2.imread('/content/Input/' + save_name , 1)
    #-----Converting image to LAB Color model----------------------------------- 
    lab= cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    #-----Splitting the LAB image to different channels-------------------------
    l, a, b = cv2.split(lab)
    #-----Applying CLAHE to L-channel-------------------------------------------
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
    cl = clahe.apply(l)
    #-----Merge the CLAHE enhanced L-channel with the a and b channel-----------
    limg = cv2.merge((cl,a,b))
    #-----Converting image from LAB Color model to RGB model--------------------
    final = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
    #_____END_____#
    cv2.imwrite('/content/Enhanced/' + save_name , final)
    success, image = vidcap.read()
    print('Read a new frame : ', success)
    count += 1
# Out:
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# Read a new frame :  True
# ...

# %%
print('Number of Frames Read : ', count)
original = cv2.imread('/content/Input/frame1300.jpg',1)
enhanced = cv2.imread('/content/Enhanced/frame1300.jpg',1)
# Out:
# Number of Frames Read :  1800

# %%
imgplot = plt.imshow(original)

# %%
imgplot = plt.imshow(enhanced)

# %%
import os
from os.path import isfile, join
def convert_frames_to_video(pathIn,pathOut,fps):
    frame_array = []
    files = [f for f in os.listdir(pathIn) if isfile(join(pathIn, f))]
 
    #for sorting the file names properly
    files.sort(key = lambda x: int(x[5:-4]))
 
    for i in range(len(files)):
        filename=pathIn + files[i]
        #reading each files
        img = cv2.imread(filename)
        height, width, layers = img.shape
        size = (width,height)
        print(filename)
        #inserting the frames into an image array
        frame_array.append(img)
 
    out = cv2.VideoWriter(pathOut,cv2.VideoWriter_fourcc(*'DIVX'), fps, size)
 
    for i in range(len(frame_array)):
        # writing to a image array
        out.write(frame_array[i])
    out.release()

# %%
# Converting Enhanced to Video
pathIn= '/content/Enhanced/'
pathOut = '/content/Bunny_Enhanced.mp4'
fps = 30.0
convert_frames_to_video(pathIn, pathOut, fps)
# Out:
# /content/Enhanced/frame0.jpg
# /content/Enhanced/frame1.jpg
# /content/Enhanced/frame2.jpg
# /content/Enhanced/frame3.jpg
# /content/Enhanced/frame4.jpg
# /content/Enhanced/frame5.jpg
# /content/Enhanced/frame6.jpg
# /content/Enhanced/frame7.jpg
# /content/Enhanced/frame8.jpg
# /content/Enhanced/frame9.jpg
# /content/Enhanced/frame10.jpg
# /content/Enhanced/frame11.jpg
# /content/Enhanced/frame12.jpg
# /content/Enhanced/frame13.jpg
# /content/Enhanced/frame14.jpg
# /content/Enhanced/frame15.jpg
# /content/Enhanced/frame16.jpg
# /content/Enhanced/frame17.jpg
# /content/Enhanced/frame18.jpg
# /content/Enhanced/frame19.jpg
# /content/Enhanced/frame20.jpg
# /content/Enhanced/frame21.jpg
# /content/Enhanced/frame22.jpg
# /content/Enhanced/frame23.jpg
# /content/Enhanced/frame24.jpg
# /content/Enhanced/frame25.jpg
# /content/Enhanced/frame26.jpg
# /content/Enhanced/frame27.jpg
# /content/Enhanced/frame28.jpg
# /content/Enhanced/frame29.jpg
# /content/Enhanced/frame30.jpg
# ...
