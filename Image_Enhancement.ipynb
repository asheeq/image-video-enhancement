# %% [markdown]
# <a href="https://colab.research.google.com/github/asheeq/image-video-enhancement/blob/master/Image_Enhancement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
from os.path import isfile, join
import time

# %%
#-----Reading the image-----------------------------------------------------
img = cv2.imread(r'/content/test.jpg', 1)
#-----Converting image to LAB Color model----------------------------------- 
start_time = time.time()
lab= cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
#-----Splitting the LAB image to different channels-------------------------
l, a, b = cv2.split(lab)
#-----Applying CLAHE to L-channel-------------------------------------------
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
cl = clahe.apply(l)
ca = clahe.apply(a)
cb = clahe.apply(b)
#-----Merge the CLAHE enhanced L-channel with the a and b channel-----------
limg = cv2.merge((cl,ca,cb))
#-----Converting image from LAB Color model to RGB model--------------------
final = cv2.cvtColor(limg, cv2.COLOR_LAB2BGR)
print("Processing time is: %s seconds." % (time.time() - start_time))
#_____END_____#
# Out:
# Processing time is: 0.023873090744018555 seconds.

# %%
imgplot = plt.imshow(img)

# %%
imgplot = plt.imshow(final)
